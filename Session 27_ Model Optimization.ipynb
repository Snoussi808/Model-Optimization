# %%
from keras.models import Sequential
from keras.layers import *
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import warnings
warnings.filterwarnings('ignore')
from tensorflow.keras.datasets import cifar10

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
x_train = x_train / 255
x_test = x_test / 255

# %%
model = Sequential([
    Conv2D(filters = 32, kernel_size = 3, activation = 'relu', input_shape = (32, 32, 3)),
    MaxPooling2D(pool_size = (2,2)),
    Conv2D(filters = 32, kernel_size = 3, activation = 'relu'),
    MaxPooling2D(pool_size = (2,2)),
    Flatten(),
    Dense(128, activation = 'relu'),
    Dense(128, activation = 'relu'),
    Dense(10, activation = 'softmax')
])

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.fit(x_train, y_train, epochs = 10, validation_data = (x_test, y_test))
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.3706 - loss: 1.7162 - val_accuracy: 0.5614 - val_loss: 1.2100
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5858 - loss: 1.1616 - val_accuracy: 0.6091 - val_loss: 1.1035
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6449 - loss: 1.0043 - val_accuracy: 0.6493 - val_loss: 1.0151
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6849 - loss: 0.8889 - val_accuracy: 0.6664 - val_loss: 0.9749
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7185 - loss: 0.7993 - val_accuracy: 0.6681 - val_loss: 0.9687
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7400 - loss: 0.7332 - val_accuracy: 0.6648 - val_loss: 0.9804
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7662 - loss: 0.6668 - val_accuracy: 0.6836 - val_loss: 0.9524
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7849 - loss: 0.6072 - val_accuracy: 0.6842 - val_loss: 0.9436
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8019 - loss: 0.5631 - val_accuracy: 0.6886 - val_loss: 0.9729
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8164 - loss: 0.5130 - val_accuracy: 0.6869 - val_loss: 0.9858

# %% [markdown]
# ## **Regularization Techniques**

# %% [markdown]
# 1- L1 ---> Lasso ----> remove unnecessary features (feature selection)
#
# 2- L2 ----> Ridge ----> high lambda value ---> too much weights ----> underfit

# %%
from tensorflow.keras.regularizers import l1, l2
model = Sequential([
    Conv2D(filters = 32, kernel_size = 3, activation = 'relu', input_shape = (32, 32, 3), kernel_regularizer = l2(0.2)),
    BatchNormalization(),
    MaxPooling2D(pool_size = (2,2)),
    Conv2D(filters = 32, kernel_size = 3, activation = 'relu'),
    MaxPooling2D(pool_size = (2,2)),
    Dropout(0.2), #prevent overfitting 
    Flatten(),
    Dense(128, activation = 'relu'),
    Dense(128, activation = 'relu'),
    Dense(10, activation = 'softmax')
])

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.fit(x_train, y_train, epochs = 10, validation_data = (x_test, y_test))
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.4124 - loss: 1.8898 - val_accuracy: 0.5597 - val_loss: 1.2951
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5883 - loss: 1.2126 - val_accuracy: 0.5802 - val_loss: 1.2485
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6369 - loss: 1.0911 - val_accuracy: 0.5741 - val_loss: 1.3333
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6668 - loss: 0.9918 - val_accuracy: 0.6338 - val_loss: 1.0904
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6891 - loss: 0.9270 - val_accuracy: 0.6637 - val_loss: 1.0383
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7062 - loss: 0.8783 - val_accuracy: 0.5151 - val_loss: 1.7070
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7243 - loss: 0.8284 - val_accuracy: 0.6042 - val_loss: 1.2227
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7319 - loss: 0.7947 - val_accuracy: 0.6895 - val_loss: 0.9722
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7439 - loss: 0.7577 - val_accuracy: 0.6402 - val_loss: 1.1490
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7586 - loss: 0.7238 - val_accuracy: 0.5610 - val_loss: 1.4312

# %% [markdown]
# ## **Parameter Search**

# %%
params = {
   # 'filters' : [32, 64],
    'kernel_size' : [3, 5],
    'dropout' : [0.2, 0.4],
    #'optimizer' : ['adam', 'sgd']
}

# %%
import itertools
keys, values = zip(*params.items())
combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]

# %%
combinations
# Out:
# [{'kernel_size': 3, 'dropout': 0.2},
#  {'kernel_size': 3, 'dropout': 0.4},
#  {'kernel_size': 5, 'dropout': 0.2},
#  {'kernel_size': 5, 'dropout': 0.4}]

# %%
best_accuracy = 0
best_params = None

for param in combinations:
    model = Sequential()
    model.add(Conv2D(32, (param['kernel_size'], param['kernel_size']), activation = 'relu', input_shape = (32, 32, 3)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Dropout(param['dropout']))
    model.add(Conv2D(32, (param['kernel_size'], param['kernel_size']), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Dropout(param['dropout']))
    model.add(Flatten())
    model.add(Dense(128, activation = 'relu'))
    model.add(Dense(128, activation = 'relu'))
    model.add(Dense(10, activation = 'softmax'))

    model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

    model.fit(x_train, y_train, epochs = 10, validation_data = (x_test, y_test